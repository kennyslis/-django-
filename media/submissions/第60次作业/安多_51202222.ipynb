# %%
class Node:
    def __init__(self,value,left=None,right=None) :
        self.value=value
        self.left=left
        self.right=right
    def print(self):
        if self.left:
            self.left.print()
        print(self.value)
        if self.right:
            self.right.print()

    def insert_node(root,node):
        if node:
            if node.value<root.value:
                if root.left:
                       insert_node(root.left,node)
                else:
                    root.left=node
            else:
                if root.right:
                    insert_node(root.right,node)
                else:
                    root.right=node 
    def split_insert(x,y,root,compute_metrics):
        if len(y.labels)>1:
            metrics=compute_metrics(x,y)
            max_feature_index=argmax(metrics)
            split_insert(x[:,max_feature_index],y[x==x[:,max_feature_index]],left,compute_metrics)
        else:
            root.insert_left()
            root.insert_right()

# %%
import cairosvg
for i in range(6):
    input_file = 'C:\Users\lenovo\Desktop\work_1\%d.svg'%i
    output_file = 'C:\Users\lenovo\Desktop\work_1%d.pdf'%i
    cairosvg.svg2pdf(url=input_file, write_to=output_file)
# Out:
# 运行具有“django (Python 3.8.20)”的单元格需要ipykernel包。
#
# 运行以下命令，将 "ipykernel" 安装到 Python 环境中。
#
# 命令: "conda install -n django ipykernel --update-deps --force-reinstall"
